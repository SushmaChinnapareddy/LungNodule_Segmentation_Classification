# %%
import numpy as np
import os
import json
from zipfile import ZipFile
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import layers, models
# Out:
# 2025-03-05 19:58:57.595173: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-05 19:58:57.609646: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-05 19:58:57.626837: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-05 19:58:57.632439: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-05 19:58:57.646170: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
import numpy as np
from glob import glob
from keras.preprocessing import image
from sklearn.model_selection import train_test_split

input_dir = "/home/gourib/LIDC-IDRI-slices"
img_shape = (128,128)  # Adjust according to your requirement
Thres = 100  # Threshold for segmentation mask

images = []
masks = []
y = []

# Step 1: Get all patient IDs
patients = sorted(os.listdir(input_dir))

# Step 2: Split patients into train and test sets
train_patients, test_patients = train_test_split(patients, train_size=0.8, random_state=12)

def load_patient_data(patient_list):
    """Load images and masks for the given list of patients"""
    images, masks, labels = [], [], []
    
    for patient in patient_list:
        patient_path = os.path.join(input_dir, patient)
        
        for nodule in os.listdir(patient_path):
            mask0, mask1, mask2, mask3 = [], [], [], []

            # Load images
            for filename in glob(f"{patient_path}/{nodule}/images/*.png"):
                img = image.load_img(filename, target_size=img_shape)
                images.append(np.asarray(img))

            # Load masks
            for filename in glob(f"{patient_path}/{nodule}/mask-0/*.png"):
                img = image.load_img(filename, target_size=img_shape)
                mask1.append(np.asarray(img))

            # Determine final mask selection
            for i in range(len(mask1)):
                white_sum = mask1[i].sum()
                label = 1 if white_sum > Thres else 0
                
                labels.append(label)
                masks.append(mask1[i])
    
    return images, masks, labels

# Step 3: Load training and testing data based on patient-wise split
x_train, mask_train, y_train = load_patient_data(train_patients)
x_test, mask_test, y_test = load_patient_data(test_patients)

# Convert to NumPy arrays
x_train, x_test = np.array(x_train)/255, np.array(x_test)/255
mask_train, mask_test = np.array(mask_train)/255, np.array(mask_test)/255
y_train, y_test = np.array(y_train), np.array(y_test)

# Print shapes
print(x_train.shape, x_test.shape)
print(mask_train.shape, mask_test.shape)
# Out:
# (12052, 128, 128, 3) (3496, 128, 128, 3)
# (12052, 128, 128, 3) (3496, 128, 128, 3)

# %%
# train_labels = np.array(y_train)
unique, counts = np.unique(y_train, return_counts=True)

# Display the count of each unique value
for u, c in zip(unique, counts):
    print(f"Value {u}: {c} occurrences")
# Out:
# Value 0: 1127 occurrences
# Value 1: 10925 occurrences

# %%
unique, counts = np.unique(y_test, return_counts=True)

# Display the count of each unique value
for u, c in zip(unique, counts):
    print(f"Value {u}: {c} occurrences")
# Out:
# Value 0: 290 occurrences
# Value 1: 3206 occurrences

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential,load_model
from keras import layers
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization,Embedding,TimeDistributed
from keras.layers import Conv2D, MaxPooling2D, ReLU, LSTM,Bidirectional,Attention,Concatenate,concatenate
from keras import regularizers, optimizers,losses
from keras.layers import DepthwiseConv2D,Add, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D,MultiHeadAttention
from keras.layers import Activation,ActivityRegularization, AvgPool2D, LeakyReLU, Conv2DTranspose
from keras.metrics import Accuracy,Recall,Precision,AUC,TruePositives,TrueNegatives,FalseNegatives,FalsePositives, SpecificityAtSensitivity,SensitivityAtSpecificity
from keras.utils import plot_model
from keras.preprocessing import image
from keras.utils import to_categorical
import numpy as np
import matplotlib
import sklearn
import matplotlib.pyplot as plt
import time
import os
import sklearn.metrics as m
from glob import glob
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
from keras.applications import MobileNetV2
from keras.layers import (Conv2D, Conv2DTranspose, Dropout, 
                                     BatchNormalization, concatenate, Input)
from keras.models import Model

# Model Name
Name = "MobileNetV2_U-Net"

# Image Shape (128x128, since MobileNetV2 supports it)
img_shape = (128, 128, 3)

def mobilenet_unet():
    # Load MobileNetV2 without fully connected layers
    mobilenet = MobileNetV2(include_top=False, weights="imagenet", input_shape=img_shape)

    # Freeze the MobileNetV2 encoder layers
    for layer in mobilenet.layers:
        layer.trainable = False

    # Encoder (MobileNetV2)
    c1 = mobilenet.get_layer("block_1_expand_relu").output   # 64x64
    c2 = mobilenet.get_layer("block_3_expand_relu").output   # 32x32
    c3 = mobilenet.get_layer("block_6_expand_relu").output   # 16x16
    c4 = mobilenet.get_layer("block_13_expand_relu").output  # 8x8
    c5 = mobilenet.get_layer("block_16_project").output      # 4x4 (Bottleneck)

    # Decoder (U-Net)
    u6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding="same")(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(256, (3, 3), activation="relu", padding="same")(u6)
    c6 = BatchNormalization()(c6)
    c6 = Dropout(0.2)(c6)

    u7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding="same")(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(128, (3, 3), activation="relu", padding="same")(u7)
    c7 = BatchNormalization()(c7)
    c7 = Dropout(0.2)(c7)

    u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding="same")(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(64, (3, 3), activation="relu", padding="same")(u8)
    c8 = BatchNormalization()(c8)
    c8 = Dropout(0.1)(c8)

    u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding="same")(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same")(u9)
    c9 = BatchNormalization()(c9)
    c9 = Dropout(0.1)(c9)

    # **Extra upsampling layer to restore 128x128 resolution**
    u10 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding="same")(c9)
    c10 = Conv2D(16, (3, 3), activation="relu", padding="same")(u10)
    c10 = BatchNormalization()(c10)

    # Final output layer (128x128x3)
    outputs = Conv2D(3, (1, 1), activation="sigmoid")(c10)

    # Define U-Net model
    model = Model(inputs=mobilenet.input, outputs=outputs, name=Name)
    
    return model

# Create the model
unet_model = mobilenet_unet()
unet_model.summary()
# Out:
# 2025-03-05 19:59:37.035843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Model: "MobileNetV2_U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 256) │    327,936 │ block_16_project… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8, 832) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ block_13_expand_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 256) │  1,917,184 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 8, 8, 256) │      1,024 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    131,200 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 320)              │            │ block_6_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │    368,768 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     32,832 │ dropout_1[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 208)              │            │ block_3_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │    119,872 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      8,224 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ block_1_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     36,896 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │      2,064 │ dropout_3[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │      2,320 │ conv2d_transpose… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │         51 │ batch_normalizat… │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,791,315 (18.28 MB)
#  Trainable params: 2,948,339 (11.25 MB)
#  Non-trainable params: 1,842,976 (7.03 MB)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
        y_true_f = tf.keras.backend.flatten(y_true)
        y_pred_f = tf.keras.backend.flatten(y_pred)
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# IoU (Jaccard Index)
def iou_coef(y_true, y_pred, smooth=1e-6):
        y_true_f = tf.keras.backend.flatten(y_true)
        y_pred_f = tf.keras.backend.flatten(y_pred)
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
        return (intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define number of folds
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Lists to store results
dice_scores = []
iou_scores = []
recall_scores = []
precision_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(x_train)):
    print(f"Training on Fold {fold + 1}/{k}")

    # Split data
    x_train_fold, x_val_fold = x_train[train_idx], x_train[val_idx]
    mask_train_fold, mask_val_fold = mask_train[train_idx], mask_train[val_idx]

    # Create a new model instance for each fold
    model = mobilenet_unet()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
                  loss=dice_loss, 
                  metrics=[dice_coef, iou_coef, tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])

    # Define callbacks
    checkpointer = ModelCheckpoint(f'Fold{fold+1}_checkpoint.weights.h5', verbose=1, save_best_only=True, save_weights_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model
    history = model.fit(x_train_fold, mask_train_fold,
                        validation_data=(x_val_fold, mask_val_fold),
                        batch_size=32, epochs=30,
                        callbacks=[checkpointer, early_stopping])

    # Evaluate the model on the validation set
    scores = model.evaluate(x_val_fold, mask_val_fold)
    dice_scores.append(scores[1])  # dice_coef
    iou_scores.append(scores[2])   # iou_coef
    recall_scores.append(scores[3])  # Recall
    precision_scores.append(scores[4])  # Precision

# Print average scores
print(f"Average Dice Coefficient: {np.mean(dice_scores):.4f}")
print(f"Average IoU: {np.mean(iou_scores):.4f}")
print(f"Average Recall: {np.mean(recall_scores):.4f}")
print(f"Average Precision: {np.mean(precision_scores):.4f}")
# Out:
# Training on Fold 1/5
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741185129.729862  326599 service.cc:146] XLA service 0x7f9ec0002010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741185129.729975  326599 service.cc:154]   StreamExecutor device (0): Tesla V100S-PCIE-32GB, Compute Capability 7.0
# 2025-03-05 20:02:09.932838: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-05 20:02:10.863311: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90201
#   3/302 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - dice_coef: 0.0123 - iou_coef: 0.0062 - loss: 0.9877 - precision: 0.0068 - recall: 0.5942
# 2025-03-05 20:02:20.087038: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_transpose_fusion_1', 8 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1741185140.165865  326599 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - dice_coef: 0.3981 - iou_coef: 0.2844 - loss: 0.6019 - precision: 0.1124 - recall: 0.7435
# 2025-03-05 20:02:37.843663: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_38', 4 bytes spill stores, 4 bytes spill loads
# Epoch 1: val_loss improved from inf to 0.47782, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 44s 90ms/step - dice_coef: 0.3987 - iou_coef: 0.2849 - loss: 0.6013 - precision: 0.1127 - recall: 0.7433 - val_dice_coef: 0.5204 - val_iou_coef: 0.3589 - val_loss: 0.4778 - val_precision: 0.4035 - val_recall: 0.8755
# Epoch 2/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7217 - iou_coef: 0.5687 - loss: 0.2783 - precision: 0.7412 - recall: 0.7153
# Epoch 2: val_loss improved from 0.47782 to 0.47298, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7217 - iou_coef: 0.5687 - loss: 0.2783 - precision: 0.7412 - recall: 0.7153 - val_dice_coef: 0.5244 - val_iou_coef: 0.3672 - val_loss: 0.4730 - val_precision: 0.9240 - val_recall: 0.3946
# Epoch 3/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7513 - iou_coef: 0.6051 - loss: 0.2487 - precision: 0.7763 - recall: 0.7407
# Epoch 3: val_loss improved from 0.47298 to 0.34156, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.7513 - iou_coef: 0.6051 - loss: 0.2487 - precision: 0.7762 - recall: 0.7407 - val_dice_coef: 0.6586 - val_iou_coef: 0.5001 - val_loss: 0.3416 - val_precision: 0.9074 - val_recall: 0.5227
# Epoch 4/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7708 - iou_coef: 0.6302 - loss: 0.2292 - precision: 0.7878 - recall: 0.7636
# Epoch 4: val_loss improved from 0.34156 to 0.26560, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7708 - iou_coef: 0.6302 - loss: 0.2292 - precision: 0.7878 - recall: 0.7636 - val_dice_coef: 0.7343 - val_iou_coef: 0.5868 - val_loss: 0.2656 - val_precision: 0.8726 - val_recall: 0.6612
# Epoch 5/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dice_coef: 0.7836 - iou_coef: 0.6471 - loss: 0.2164 - precision: 0.8010 - recall: 0.7796
# Epoch 5: val_loss improved from 0.26560 to 0.23125, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7836 - iou_coef: 0.6470 - loss: 0.2164 - precision: 0.8010 - recall: 0.7795 - val_dice_coef: 0.7682 - val_iou_coef: 0.6294 - val_loss: 0.2313 - val_precision: 0.8529 - val_recall: 0.7383
# Epoch 6/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7812 - iou_coef: 0.6436 - loss: 0.2188 - precision: 0.8018 - recall: 0.7723
# Epoch 6: val_loss did not improve from 0.23125
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7812 - iou_coef: 0.6436 - loss: 0.2188 - precision: 0.8018 - recall: 0.7723 - val_dice_coef: 0.7317 - val_iou_coef: 0.5844 - val_loss: 0.2684 - val_precision: 0.8685 - val_recall: 0.6581
# Epoch 7/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7893 - iou_coef: 0.6541 - loss: 0.2107 - precision: 0.8039 - recall: 0.7830
# Epoch 7: val_loss did not improve from 0.23125
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - dice_coef: 0.7893 - iou_coef: 0.6541 - loss: 0.2107 - precision: 0.8040 - recall: 0.7830 - val_dice_coef: 0.7236 - val_iou_coef: 0.5745 - val_loss: 0.2753 - val_precision: 0.7361 - val_recall: 0.7774
# Epoch 8/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8056 - iou_coef: 0.6768 - loss: 0.1944 - precision: 0.8200 - recall: 0.8034
# Epoch 8: val_loss improved from 0.23125 to 0.22778, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8055 - iou_coef: 0.6767 - loss: 0.1945 - precision: 0.8200 - recall: 0.8034 - val_dice_coef: 0.7713 - val_iou_coef: 0.6323 - val_loss: 0.2278 - val_precision: 0.8476 - val_recall: 0.7498
# Epoch 9/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7947 - iou_coef: 0.6623 - loss: 0.2052 - precision: 0.8089 - recall: 0.7935
# Epoch 9: val_loss improved from 0.22778 to 0.21087, saving model to Fold1_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7947 - iou_coef: 0.6624 - loss: 0.2052 - precision: 0.8089 - recall: 0.7935 - val_dice_coef: 0.7884 - val_iou_coef: 0.6546 - val_loss: 0.2109 - val_precision: 0.7777 - val_recall: 0.8422
# Epoch 10/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8045 - iou_coef: 0.6746 - loss: 0.1955 - precision: 0.8178 - recall: 0.8012
# Epoch 10: val_loss did not improve from 0.21087
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8045 - iou_coef: 0.6746 - loss: 0.1955 - precision: 0.8178 - recall: 0.8011 - val_dice_coef: 0.7751 - val_iou_coef: 0.6375 - val_loss: 0.2245 - val_precision: 0.8551 - val_recall: 0.7462
# Epoch 11/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8074 - iou_coef: 0.6795 - loss: 0.1926 - precision: 0.8256 - recall: 0.8013
# Epoch 11: val_loss did not improve from 0.21087
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8074 - iou_coef: 0.6795 - loss: 0.1926 - precision: 0.8255 - recall: 0.8013 - val_dice_coef: 0.7596 - val_iou_coef: 0.6171 - val_loss: 0.2384 - val_precision: 0.7057 - val_recall: 0.8772
# Epoch 12/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8081 - iou_coef: 0.6806 - loss: 0.1919 - precision: 0.8247 - recall: 0.8041
# Epoch 12: val_loss did not improve from 0.21087
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8081 - iou_coef: 0.6806 - loss: 0.1919 - precision: 0.8247 - recall: 0.8041 - val_dice_coef: 0.7829 - val_iou_coef: 0.6481 - val_loss: 0.2168 - val_precision: 0.8277 - val_recall: 0.7857
# Epoch 13/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8102 - iou_coef: 0.6830 - loss: 0.1898 - precision: 0.8249 - recall: 0.8044
# Epoch 13: val_loss did not improve from 0.21087
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8102 - iou_coef: 0.6829 - loss: 0.1898 - precision: 0.8249 - recall: 0.8043 - val_dice_coef: 0.7674 - val_iou_coef: 0.6274 - val_loss: 0.2310 - val_precision: 0.7343 - val_recall: 0.8613
# Epoch 14/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8116 - iou_coef: 0.6850 - loss: 0.1884 - precision: 0.8248 - recall: 0.8085
# Epoch 14: val_loss did not improve from 0.21087
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8116 - iou_coef: 0.6850 - loss: 0.1884 - precision: 0.8248 - recall: 0.8085 - val_dice_coef: 0.6972 - val_iou_coef: 0.5424 - val_loss: 0.3025 - val_precision: 0.9012 - val_recall: 0.5904
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - dice_coef: 0.7893 - iou_coef: 0.6559 - loss: 0.2106 - precision: 0.7811 - recall: 0.8390
# Training on Fold 2/5
# Epoch 1/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - dice_coef: 0.3891 - iou_coef: 0.2755 - loss: 0.6109 - precision_1: 0.1018 - recall_1: 0.7308
# Epoch 1: val_loss improved from inf to 0.73510, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 37s 78ms/step - dice_coef: 0.3897 - iou_coef: 0.2760 - loss: 0.6103 - precision_1: 0.1021 - recall_1: 0.7306 - val_dice_coef: 0.2644 - val_iou_coef: 0.1550 - val_loss: 0.7351 - val_precision_1: 0.1591 - val_recall_1: 0.9462
# Epoch 2/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7221 - iou_coef: 0.5684 - loss: 0.2779 - precision_1: 0.7392 - recall_1: 0.7138
# Epoch 2: val_loss improved from 0.73510 to 0.40141, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7221 - iou_coef: 0.5684 - loss: 0.2779 - precision_1: 0.7392 - recall_1: 0.7138 - val_dice_coef: 0.5997 - val_iou_coef: 0.4413 - val_loss: 0.4014 - val_precision_1: 0.9109 - val_recall_1: 0.4437
# Epoch 3/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dice_coef: 0.7487 - iou_coef: 0.6014 - loss: 0.2513 - precision_1: 0.7651 - recall_1: 0.7405
# Epoch 3: val_loss improved from 0.40141 to 0.26225, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7487 - iou_coef: 0.6014 - loss: 0.2512 - precision_1: 0.7651 - recall_1: 0.7406 - val_dice_coef: 0.7378 - val_iou_coef: 0.5905 - val_loss: 0.2622 - val_precision_1: 0.7201 - val_recall_1: 0.7734
# Epoch 4/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7589 - iou_coef: 0.6146 - loss: 0.2411 - precision_1: 0.7815 - recall_1: 0.7460
# Epoch 4: val_loss improved from 0.26225 to 0.24987, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7589 - iou_coef: 0.6146 - loss: 0.2411 - precision_1: 0.7815 - recall_1: 0.7460 - val_dice_coef: 0.7500 - val_iou_coef: 0.6054 - val_loss: 0.2499 - val_precision_1: 0.7303 - val_recall_1: 0.7943
# Epoch 5/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7839 - iou_coef: 0.6472 - loss: 0.2161 - precision_1: 0.8011 - recall_1: 0.7760
# Epoch 5: val_loss did not improve from 0.24987
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7838 - iou_coef: 0.6472 - loss: 0.2162 - precision_1: 0.8011 - recall_1: 0.7760 - val_dice_coef: 0.7360 - val_iou_coef: 0.5891 - val_loss: 0.2641 - val_precision_1: 0.8944 - val_recall_1: 0.6355
# Epoch 6/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7914 - iou_coef: 0.6573 - loss: 0.2086 - precision_1: 0.8068 - recall_1: 0.7855
# Epoch 6: val_loss improved from 0.24987 to 0.23488, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7914 - iou_coef: 0.6573 - loss: 0.2086 - precision_1: 0.8067 - recall_1: 0.7855 - val_dice_coef: 0.7654 - val_iou_coef: 0.6256 - val_loss: 0.2349 - val_precision_1: 0.8427 - val_recall_1: 0.7119
# Epoch 7/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7907 - iou_coef: 0.6568 - loss: 0.2093 - precision_1: 0.8061 - recall_1: 0.7861
# Epoch 7: val_loss did not improve from 0.23488
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7907 - iou_coef: 0.6568 - loss: 0.2093 - precision_1: 0.8060 - recall_1: 0.7861 - val_dice_coef: 0.7490 - val_iou_coef: 0.6043 - val_loss: 0.2511 - val_precision_1: 0.8421 - val_recall_1: 0.6822
# Epoch 8/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7899 - iou_coef: 0.6556 - loss: 0.2101 - precision_1: 0.8110 - recall_1: 0.7826
# Epoch 8: val_loss did not improve from 0.23488
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7899 - iou_coef: 0.6556 - loss: 0.2101 - precision_1: 0.8110 - recall_1: 0.7827 - val_dice_coef: 0.5182 - val_iou_coef: 0.3564 - val_loss: 0.4822 - val_precision_1: 0.4018 - val_recall_1: 0.8346
# Epoch 9/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7932 - iou_coef: 0.6598 - loss: 0.2067 - precision_1: 0.8115 - recall_1: 0.7844
# Epoch 9: val_loss did not improve from 0.23488
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7933 - iou_coef: 0.6598 - loss: 0.2067 - precision_1: 0.8115 - recall_1: 0.7845 - val_dice_coef: 0.7560 - val_iou_coef: 0.6135 - val_loss: 0.2438 - val_precision_1: 0.8861 - val_recall_1: 0.6697
# Epoch 10/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7988 - iou_coef: 0.6672 - loss: 0.2012 - precision_1: 0.8166 - recall_1: 0.7905
# Epoch 10: val_loss improved from 0.23488 to 0.22488, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - dice_coef: 0.7988 - iou_coef: 0.6672 - loss: 0.2012 - precision_1: 0.8165 - recall_1: 0.7905 - val_dice_coef: 0.7749 - val_iou_coef: 0.6375 - val_loss: 0.2249 - val_precision_1: 0.8261 - val_recall_1: 0.7441
# Epoch 11/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8026 - iou_coef: 0.6723 - loss: 0.1974 - precision_1: 0.8187 - recall_1: 0.7966
# Epoch 11: val_loss improved from 0.22488 to 0.21649, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - dice_coef: 0.8026 - iou_coef: 0.6723 - loss: 0.1974 - precision_1: 0.8187 - recall_1: 0.7966 - val_dice_coef: 0.7835 - val_iou_coef: 0.6474 - val_loss: 0.2165 - val_precision_1: 0.7638 - val_recall_1: 0.8262
# Epoch 12/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8084 - iou_coef: 0.6804 - loss: 0.1916 - precision_1: 0.8160 - recall_1: 0.8097
# Epoch 12: val_loss did not improve from 0.21649
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8084 - iou_coef: 0.6804 - loss: 0.1916 - precision_1: 0.8160 - recall_1: 0.8097 - val_dice_coef: 0.7481 - val_iou_coef: 0.6039 - val_loss: 0.2521 - val_precision_1: 0.9156 - val_recall_1: 0.6449
# Epoch 13/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8095 - iou_coef: 0.6823 - loss: 0.1905 - precision_1: 0.8319 - recall_1: 0.7989
# Epoch 13: val_loss did not improve from 0.21649
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8095 - iou_coef: 0.6823 - loss: 0.1905 - precision_1: 0.8319 - recall_1: 0.7990 - val_dice_coef: 0.7827 - val_iou_coef: 0.6481 - val_loss: 0.2173 - val_precision_1: 0.8555 - val_recall_1: 0.7357
# Epoch 14/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8157 - iou_coef: 0.6908 - loss: 0.1843 - precision_1: 0.8337 - recall_1: 0.8073
# Epoch 14: val_loss did not improve from 0.21649
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8157 - iou_coef: 0.6908 - loss: 0.1843 - precision_1: 0.8337 - recall_1: 0.8073 - val_dice_coef: 0.7810 - val_iou_coef: 0.6448 - val_loss: 0.2188 - val_precision_1: 0.7504 - val_recall_1: 0.8370
# Epoch 15/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8124 - iou_coef: 0.6862 - loss: 0.1876 - precision_1: 0.8286 - recall_1: 0.8073
# Epoch 15: val_loss improved from 0.21649 to 0.20764, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - dice_coef: 0.8124 - iou_coef: 0.6862 - loss: 0.1876 - precision_1: 0.8286 - recall_1: 0.8073 - val_dice_coef: 0.7922 - val_iou_coef: 0.6594 - val_loss: 0.2076 - val_precision_1: 0.7837 - val_recall_1: 0.8216
# Epoch 16/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8133 - iou_coef: 0.6871 - loss: 0.1867 - precision_1: 0.8279 - recall_1: 0.8067
# Epoch 16: val_loss improved from 0.20764 to 0.20213, saving model to Fold2_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - dice_coef: 0.8133 - iou_coef: 0.6871 - loss: 0.1867 - precision_1: 0.8279 - recall_1: 0.8067 - val_dice_coef: 0.7978 - val_iou_coef: 0.6674 - val_loss: 0.2021 - val_precision_1: 0.8296 - val_recall_1: 0.7847
# Epoch 17/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8181 - iou_coef: 0.6944 - loss: 0.1819 - precision_1: 0.8323 - recall_1: 0.8163
# Epoch 17: val_loss did not improve from 0.20213
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8181 - iou_coef: 0.6944 - loss: 0.1819 - precision_1: 0.8323 - recall_1: 0.8163 - val_dice_coef: 0.7457 - val_iou_coef: 0.5999 - val_loss: 0.2544 - val_precision_1: 0.7479 - val_recall_1: 0.7605
# Epoch 18/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8153 - iou_coef: 0.6903 - loss: 0.1847 - precision_1: 0.8261 - recall_1: 0.8153
# Epoch 18: val_loss did not improve from 0.20213
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8153 - iou_coef: 0.6903 - loss: 0.1847 - precision_1: 0.8262 - recall_1: 0.8153 - val_dice_coef: 0.7850 - val_iou_coef: 0.6500 - val_loss: 0.2148 - val_precision_1: 0.7771 - val_recall_1: 0.8171
# Epoch 19/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8168 - iou_coef: 0.6924 - loss: 0.1832 - precision_1: 0.8259 - recall_1: 0.8200
# Epoch 19: val_loss did not improve from 0.20213
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8168 - iou_coef: 0.6924 - loss: 0.1832 - precision_1: 0.8260 - recall_1: 0.8200 - val_dice_coef: 0.7621 - val_iou_coef: 0.6207 - val_loss: 0.2380 - val_precision_1: 0.7257 - val_recall_1: 0.8353
# Epoch 20/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8168 - iou_coef: 0.6923 - loss: 0.1832 - precision_1: 0.8343 - recall_1: 0.8112
# Epoch 20: val_loss did not improve from 0.20213
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8168 - iou_coef: 0.6922 - loss: 0.1832 - precision_1: 0.8343 - recall_1: 0.8112 - val_dice_coef: 0.7748 - val_iou_coef: 0.6382 - val_loss: 0.2257 - val_precision_1: 0.8627 - val_recall_1: 0.7174
# Epoch 21/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8205 - iou_coef: 0.6980 - loss: 0.1795 - precision_1: 0.8335 - recall_1: 0.8187
# Epoch 21: val_loss did not improve from 0.20213
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8205 - iou_coef: 0.6980 - loss: 0.1795 - precision_1: 0.8335 - recall_1: 0.8187 - val_dice_coef: 0.7906 - val_iou_coef: 0.6571 - val_loss: 0.2093 - val_precision_1: 0.7646 - val_recall_1: 0.8411
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - dice_coef: 0.8019 - iou_coef: 0.6729 - loss: 0.1981 - precision_1: 0.8357 - recall_1: 0.7881
# Training on Fold 3/5
# Epoch 1/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - dice_coef: 0.3896 - iou_coef: 0.2763 - loss: 0.6104 - precision_2: 0.1002 - recall_2: 0.7365
# Epoch 1: val_loss improved from inf to 0.35646, saving model to Fold3_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - dice_coef: 0.3902 - iou_coef: 0.2767 - loss: 0.6098 - precision_2: 0.1004 - recall_2: 0.7363 - val_dice_coef: 0.6428 - val_iou_coef: 0.4815 - val_loss: 0.3565 - val_precision_2: 0.6169 - val_recall_2: 0.7165
# Epoch 2/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7134 - iou_coef: 0.5580 - loss: 0.2866 - precision_2: 0.7387 - recall_2: 0.6972
# Epoch 2: val_loss did not improve from 0.35646
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7134 - iou_coef: 0.5581 - loss: 0.2866 - precision_2: 0.7387 - recall_2: 0.6973 - val_dice_coef: 0.6365 - val_iou_coef: 0.4782 - val_loss: 0.3644 - val_precision_2: 0.8979 - val_recall_2: 0.4807
# Epoch 3/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7493 - iou_coef: 0.6027 - loss: 0.2507 - precision_2: 0.7742 - recall_2: 0.7365
# Epoch 3: val_loss improved from 0.35646 to 0.27298, saving model to Fold3_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7493 - iou_coef: 0.6028 - loss: 0.2507 - precision_2: 0.7742 - recall_2: 0.7366 - val_dice_coef: 0.7267 - val_iou_coef: 0.5770 - val_loss: 0.2730 - val_precision_2: 0.7487 - val_recall_2: 0.7324
# Epoch 4/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7651 - iou_coef: 0.6229 - loss: 0.2349 - precision_2: 0.7909 - recall_2: 0.7519
# Epoch 4: val_loss did not improve from 0.27298
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7652 - iou_coef: 0.6230 - loss: 0.2348 - precision_2: 0.7909 - recall_2: 0.7520 - val_dice_coef: 0.4949 - val_iou_coef: 0.3401 - val_loss: 0.5057 - val_precision_2: 0.9527 - val_recall_2: 0.3348
# Epoch 5/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7807 - iou_coef: 0.6427 - loss: 0.2193 - precision_2: 0.7986 - recall_2: 0.7725
# Epoch 5: val_loss improved from 0.27298 to 0.22926, saving model to Fold3_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7807 - iou_coef: 0.6427 - loss: 0.2193 - precision_2: 0.7986 - recall_2: 0.7725 - val_dice_coef: 0.7702 - val_iou_coef: 0.6313 - val_loss: 0.2293 - val_precision_2: 0.8652 - val_recall_2: 0.7098
# Epoch 6/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7820 - iou_coef: 0.6447 - loss: 0.2180 - precision_2: 0.7974 - recall_2: 0.7778
# Epoch 6: val_loss did not improve from 0.22926
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7820 - iou_coef: 0.6447 - loss: 0.2180 - precision_2: 0.7974 - recall_2: 0.7778 - val_dice_coef: 0.7639 - val_iou_coef: 0.6237 - val_loss: 0.2363 - val_precision_2: 0.8329 - val_recall_2: 0.7202
# Epoch 7/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7883 - iou_coef: 0.6535 - loss: 0.2117 - precision_2: 0.7977 - recall_2: 0.7922
# Epoch 7: val_loss did not improve from 0.22926
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7883 - iou_coef: 0.6535 - loss: 0.2117 - precision_2: 0.7977 - recall_2: 0.7922 - val_dice_coef: 0.7673 - val_iou_coef: 0.6266 - val_loss: 0.2326 - val_precision_2: 0.7346 - val_recall_2: 0.8342
# Epoch 8/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7927 - iou_coef: 0.6591 - loss: 0.2073 - precision_2: 0.8079 - recall_2: 0.7889
# Epoch 8: val_loss improved from 0.22926 to 0.21010, saving model to Fold3_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.7927 - iou_coef: 0.6591 - loss: 0.2073 - precision_2: 0.8079 - recall_2: 0.7888 - val_dice_coef: 0.7896 - val_iou_coef: 0.6566 - val_loss: 0.2101 - val_precision_2: 0.7828 - val_recall_2: 0.8225
# Epoch 9/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7899 - iou_coef: 0.6551 - loss: 0.2101 - precision_2: 0.8032 - recall_2: 0.7871
# Epoch 9: val_loss improved from 0.21010 to 0.20988, saving model to Fold3_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.7899 - iou_coef: 0.6552 - loss: 0.2101 - precision_2: 0.8033 - recall_2: 0.7872 - val_dice_coef: 0.7892 - val_iou_coef: 0.6566 - val_loss: 0.2099 - val_precision_2: 0.8132 - val_recall_2: 0.7924
# Epoch 10/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8058 - iou_coef: 0.6775 - loss: 0.1942 - precision_2: 0.8208 - recall_2: 0.8007
# Epoch 10: val_loss did not improve from 0.20988
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - dice_coef: 0.8058 - iou_coef: 0.6774 - loss: 0.1942 - precision_2: 0.8208 - recall_2: 0.8007 - val_dice_coef: 0.7886 - val_iou_coef: 0.6553 - val_loss: 0.2113 - val_precision_2: 0.8045 - val_recall_2: 0.7986
# Epoch 11/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8005 - iou_coef: 0.6702 - loss: 0.1995 - precision_2: 0.8121 - recall_2: 0.8023
# Epoch 11: val_loss did not improve from 0.20988
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8005 - iou_coef: 0.6702 - loss: 0.1995 - precision_2: 0.8121 - recall_2: 0.8023 - val_dice_coef: 0.6411 - val_iou_coef: 0.4794 - val_loss: 0.3595 - val_precision_2: 0.5182 - val_recall_2: 0.9224
# Epoch 12/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8095 - iou_coef: 0.6821 - loss: 0.1905 - precision_2: 0.8189 - recall_2: 0.8097
# Epoch 12: val_loss did not improve from 0.20988
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8095 - iou_coef: 0.6820 - loss: 0.1905 - precision_2: 0.8189 - recall_2: 0.8097 - val_dice_coef: 0.7493 - val_iou_coef: 0.6056 - val_loss: 0.2497 - val_precision_2: 0.9037 - val_recall_2: 0.6623
# Epoch 13/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8166 - iou_coef: 0.6918 - loss: 0.1834 - precision_2: 0.8290 - recall_2: 0.8138
# Epoch 13: val_loss did not improve from 0.20988
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8166 - iou_coef: 0.6918 - loss: 0.1834 - precision_2: 0.8290 - recall_2: 0.8138 - val_dice_coef: 0.7816 - val_iou_coef: 0.6456 - val_loss: 0.2182 - val_precision_2: 0.7768 - val_recall_2: 0.8168
# Epoch 14/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8095 - iou_coef: 0.6825 - loss: 0.1905 - precision_2: 0.8229 - recall_2: 0.8092
# Epoch 14: val_loss did not improve from 0.20988
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8094 - iou_coef: 0.6825 - loss: 0.1905 - precision_2: 0.8229 - recall_2: 0.8092 - val_dice_coef: 0.7859 - val_iou_coef: 0.6516 - val_loss: 0.2138 - val_precision_2: 0.7986 - val_recall_2: 0.8050
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - dice_coef: 0.7903 - iou_coef: 0.6576 - loss: 0.2096 - precision_2: 0.8037 - recall_2: 0.8036
# Training on Fold 4/5
# Epoch 1/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - dice_coef: 0.4006 - iou_coef: 0.2843 - loss: 0.5994 - precision_3: 0.1271 - recall_3: 0.7237
# Epoch 1: val_loss improved from inf to 0.29485, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 38s 80ms/step - dice_coef: 0.4012 - iou_coef: 0.2847 - loss: 0.5988 - precision_3: 0.1274 - recall_3: 0.7236 - val_dice_coef: 0.7023 - val_iou_coef: 0.5493 - val_loss: 0.2949 - val_precision_3: 0.6895 - val_recall_3: 0.7765
# Epoch 2/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7191 - iou_coef: 0.5651 - loss: 0.2809 - precision_3: 0.7380 - recall_3: 0.7099
# Epoch 2: val_loss improved from 0.29485 to 0.29329, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7191 - iou_coef: 0.5651 - loss: 0.2808 - precision_3: 0.7381 - recall_3: 0.7099 - val_dice_coef: 0.7046 - val_iou_coef: 0.5515 - val_loss: 0.2933 - val_precision_3: 0.6522 - val_recall_3: 0.8395
# Epoch 3/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7453 - iou_coef: 0.5974 - loss: 0.2547 - precision_3: 0.7664 - recall_3: 0.7358
# Epoch 3: val_loss did not improve from 0.29329
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7453 - iou_coef: 0.5974 - loss: 0.2547 - precision_3: 0.7664 - recall_3: 0.7358 - val_dice_coef: 0.6898 - val_iou_coef: 0.5374 - val_loss: 0.3096 - val_precision_3: 0.8621 - val_recall_3: 0.6063
# Epoch 4/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7510 - iou_coef: 0.6046 - loss: 0.2490 - precision_3: 0.7804 - recall_3: 0.7354
# Epoch 4: val_loss improved from 0.29329 to 0.24748, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7510 - iou_coef: 0.6047 - loss: 0.2489 - precision_3: 0.7804 - recall_3: 0.7355 - val_dice_coef: 0.7501 - val_iou_coef: 0.6066 - val_loss: 0.2475 - val_precision_3: 0.7312 - val_recall_3: 0.8201
# Epoch 5/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7649 - iou_coef: 0.6231 - loss: 0.2351 - precision_3: 0.7847 - recall_3: 0.7558
# Epoch 5: val_loss improved from 0.24748 to 0.22792, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.7650 - iou_coef: 0.6231 - loss: 0.2350 - precision_3: 0.7848 - recall_3: 0.7558 - val_dice_coef: 0.7710 - val_iou_coef: 0.6330 - val_loss: 0.2279 - val_precision_3: 0.8114 - val_recall_3: 0.7736
# Epoch 6/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7810 - iou_coef: 0.6441 - loss: 0.2189 - precision_3: 0.7930 - recall_3: 0.7826
# Epoch 6: val_loss did not improve from 0.22792
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7810 - iou_coef: 0.6441 - loss: 0.2189 - precision_3: 0.7930 - recall_3: 0.7826 - val_dice_coef: 0.7028 - val_iou_coef: 0.5485 - val_loss: 0.2949 - val_precision_3: 0.6180 - val_recall_3: 0.8895
# Epoch 7/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7832 - iou_coef: 0.6460 - loss: 0.2168 - precision_3: 0.7999 - recall_3: 0.7767
# Epoch 7: val_loss did not improve from 0.22792
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7832 - iou_coef: 0.6460 - loss: 0.2168 - precision_3: 0.7999 - recall_3: 0.7767 - val_dice_coef: 0.6993 - val_iou_coef: 0.5447 - val_loss: 0.2985 - val_precision_3: 0.6026 - val_recall_3: 0.9143
# Epoch 8/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7900 - iou_coef: 0.6558 - loss: 0.2100 - precision_3: 0.8069 - recall_3: 0.7858
# Epoch 8: val_loss did not improve from 0.22792
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - dice_coef: 0.7900 - iou_coef: 0.6558 - loss: 0.2100 - precision_3: 0.8069 - recall_3: 0.7858 - val_dice_coef: 0.7237 - val_iou_coef: 0.5731 - val_loss: 0.2745 - val_precision_3: 0.6452 - val_recall_3: 0.8900
# Epoch 9/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7915 - iou_coef: 0.6578 - loss: 0.2085 - precision_3: 0.8019 - recall_3: 0.7916
# Epoch 9: val_loss improved from 0.22792 to 0.21295, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.7915 - iou_coef: 0.6578 - loss: 0.2085 - precision_3: 0.8019 - recall_3: 0.7916 - val_dice_coef: 0.7851 - val_iou_coef: 0.6509 - val_loss: 0.2129 - val_precision_3: 0.7771 - val_recall_3: 0.8373
# Epoch 10/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8042 - iou_coef: 0.6750 - loss: 0.1958 - precision_3: 0.8184 - recall_3: 0.7987
# Epoch 10: val_loss did not improve from 0.21295
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8041 - iou_coef: 0.6750 - loss: 0.1958 - precision_3: 0.8184 - recall_3: 0.7987 - val_dice_coef: 0.7674 - val_iou_coef: 0.6270 - val_loss: 0.2313 - val_precision_3: 0.7133 - val_recall_3: 0.8813
# Epoch 11/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8055 - iou_coef: 0.6765 - loss: 0.1945 - precision_3: 0.8223 - recall_3: 0.7987
# Epoch 11: val_loss did not improve from 0.21295
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8055 - iou_coef: 0.6765 - loss: 0.1945 - precision_3: 0.8223 - recall_3: 0.7987 - val_dice_coef: 0.6512 - val_iou_coef: 0.4916 - val_loss: 0.3461 - val_precision_3: 0.5582 - val_recall_3: 0.8731
# Epoch 12/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8080 - iou_coef: 0.6801 - loss: 0.1920 - precision_3: 0.8304 - recall_3: 0.7976
# Epoch 12: val_loss did not improve from 0.21295
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8080 - iou_coef: 0.6801 - loss: 0.1920 - precision_3: 0.8304 - recall_3: 0.7976 - val_dice_coef: 0.7507 - val_iou_coef: 0.6058 - val_loss: 0.2478 - val_precision_3: 0.6751 - val_recall_3: 0.8989
# Epoch 13/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8109 - iou_coef: 0.6841 - loss: 0.1891 - precision_3: 0.8259 - recall_3: 0.8054
# Epoch 13: val_loss improved from 0.21295 to 0.21108, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8109 - iou_coef: 0.6841 - loss: 0.1891 - precision_3: 0.8258 - recall_3: 0.8054 - val_dice_coef: 0.7871 - val_iou_coef: 0.6539 - val_loss: 0.2111 - val_precision_3: 0.7638 - val_recall_3: 0.8591
# Epoch 14/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8085 - iou_coef: 0.6813 - loss: 0.1915 - precision_3: 0.8195 - recall_3: 0.8083
# Epoch 14: val_loss improved from 0.21108 to 0.21082, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8085 - iou_coef: 0.6813 - loss: 0.1915 - precision_3: 0.8195 - recall_3: 0.8083 - val_dice_coef: 0.7877 - val_iou_coef: 0.6560 - val_loss: 0.2108 - val_precision_3: 0.8559 - val_recall_3: 0.7645
# Epoch 15/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8108 - iou_coef: 0.6842 - loss: 0.1891 - precision_3: 0.8210 - recall_3: 0.8118
# Epoch 15: val_loss improved from 0.21082 to 0.20496, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - dice_coef: 0.8109 - iou_coef: 0.6842 - loss: 0.1891 - precision_3: 0.8210 - recall_3: 0.8118 - val_dice_coef: 0.7936 - val_iou_coef: 0.6640 - val_loss: 0.2050 - val_precision_3: 0.8375 - val_recall_3: 0.7907
# Epoch 16/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8193 - iou_coef: 0.6958 - loss: 0.1807 - precision_3: 0.8271 - recall_3: 0.8202
# Epoch 16: val_loss did not improve from 0.20496
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8193 - iou_coef: 0.6957 - loss: 0.1807 - precision_3: 0.8270 - recall_3: 0.8202 - val_dice_coef: 0.7727 - val_iou_coef: 0.6356 - val_loss: 0.2261 - val_precision_3: 0.8777 - val_recall_3: 0.7160
# Epoch 17/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8120 - iou_coef: 0.6855 - loss: 0.1879 - precision_3: 0.8241 - recall_3: 0.8109
# Epoch 17: val_loss did not improve from 0.20496
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8121 - iou_coef: 0.6855 - loss: 0.1879 - precision_3: 0.8241 - recall_3: 0.8109 - val_dice_coef: 0.7901 - val_iou_coef: 0.6588 - val_loss: 0.2081 - val_precision_3: 0.8509 - val_recall_3: 0.7799
# Epoch 18/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8145 - iou_coef: 0.6892 - loss: 0.1855 - precision_3: 0.8266 - recall_3: 0.8124
# Epoch 18: val_loss did not improve from 0.20496
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8145 - iou_coef: 0.6892 - loss: 0.1855 - precision_3: 0.8266 - recall_3: 0.8124 - val_dice_coef: 0.7481 - val_iou_coef: 0.6054 - val_loss: 0.2507 - val_precision_3: 0.8974 - val_recall_3: 0.6779
# Epoch 19/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8180 - iou_coef: 0.6943 - loss: 0.1820 - precision_3: 0.8305 - recall_3: 0.8160
# Epoch 19: val_loss did not improve from 0.20496
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8180 - iou_coef: 0.6943 - loss: 0.1820 - precision_3: 0.8305 - recall_3: 0.8160 - val_dice_coef: 0.7833 - val_iou_coef: 0.6505 - val_loss: 0.2142 - val_precision_3: 0.7967 - val_recall_3: 0.8197
# Epoch 20/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8222 - iou_coef: 0.6997 - loss: 0.1778 - precision_3: 0.8364 - recall_3: 0.8172
# Epoch 20: val_loss improved from 0.20496 to 0.19482, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8222 - iou_coef: 0.6997 - loss: 0.1778 - precision_3: 0.8364 - recall_3: 0.8172 - val_dice_coef: 0.8041 - val_iou_coef: 0.6762 - val_loss: 0.1948 - val_precision_3: 0.8130 - val_recall_3: 0.8313
# Epoch 21/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8226 - iou_coef: 0.7005 - loss: 0.1774 - precision_3: 0.8382 - recall_3: 0.8172
# Epoch 21: val_loss improved from 0.19482 to 0.19161, saving model to Fold4_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - dice_coef: 0.8226 - iou_coef: 0.7005 - loss: 0.1774 - precision_3: 0.8381 - recall_3: 0.8172 - val_dice_coef: 0.8069 - val_iou_coef: 0.6806 - val_loss: 0.1916 - val_precision_3: 0.8275 - val_recall_3: 0.8242
# Epoch 22/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8213 - iou_coef: 0.6984 - loss: 0.1787 - precision_3: 0.8277 - recall_3: 0.8237
# Epoch 22: val_loss did not improve from 0.19161
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8213 - iou_coef: 0.6985 - loss: 0.1787 - precision_3: 0.8278 - recall_3: 0.8237 - val_dice_coef: 0.6790 - val_iou_coef: 0.5221 - val_loss: 0.3198 - val_precision_3: 0.5768 - val_recall_3: 0.9057
# Epoch 23/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8246 - iou_coef: 0.7038 - loss: 0.1754 - precision_3: 0.8400 - recall_3: 0.8202
# Epoch 23: val_loss did not improve from 0.19161
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8245 - iou_coef: 0.7038 - loss: 0.1755 - precision_3: 0.8400 - recall_3: 0.8202 - val_dice_coef: 0.7971 - val_iou_coef: 0.6672 - val_loss: 0.2017 - val_precision_3: 0.8448 - val_recall_3: 0.7893
# Epoch 24/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8273 - iou_coef: 0.7068 - loss: 0.1727 - precision_3: 0.8394 - recall_3: 0.8230
# Epoch 24: val_loss did not improve from 0.19161
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8273 - iou_coef: 0.7068 - loss: 0.1727 - precision_3: 0.8394 - recall_3: 0.8230 - val_dice_coef: 0.7847 - val_iou_coef: 0.6499 - val_loss: 0.2141 - val_precision_3: 0.7481 - val_recall_3: 0.8707
# Epoch 25/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8282 - iou_coef: 0.7083 - loss: 0.1718 - precision_3: 0.8372 - recall_3: 0.8284
# Epoch 25: val_loss did not improve from 0.19161
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8282 - iou_coef: 0.7083 - loss: 0.1718 - precision_3: 0.8372 - recall_3: 0.8283 - val_dice_coef: 0.8010 - val_iou_coef: 0.6719 - val_loss: 0.1975 - val_precision_3: 0.7916 - val_recall_3: 0.8500
# Epoch 26/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8289 - iou_coef: 0.7093 - loss: 0.1711 - precision_3: 0.8376 - recall_3: 0.8282
# Epoch 26: val_loss did not improve from 0.19161
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8289 - iou_coef: 0.7093 - loss: 0.1711 - precision_3: 0.8377 - recall_3: 0.8281 - val_dice_coef: 0.7946 - val_iou_coef: 0.6643 - val_loss: 0.2037 - val_precision_3: 0.8135 - val_recall_3: 0.8217
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - dice_coef: 0.8044 - iou_coef: 0.6773 - loss: 0.1956 - precision_3: 0.8223 - recall_3: 0.8242
# Training on Fold 5/5
# Epoch 1/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - dice_coef: 0.3887 - iou_coef: 0.2749 - loss: 0.6113 - precision_4: 0.1049 - recall_4: 0.7433
# Epoch 1: val_loss improved from inf to 0.79341, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 38s 81ms/step - dice_coef: 0.3893 - iou_coef: 0.2753 - loss: 0.6107 - precision_4: 0.1052 - recall_4: 0.7431 - val_dice_coef: 0.2082 - val_iou_coef: 0.1236 - val_loss: 0.7934 - val_precision_4: 0.9760 - val_recall_4: 0.1219
# Epoch 2/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7136 - iou_coef: 0.5582 - loss: 0.2864 - precision_4: 0.7333 - recall_4: 0.7035
# Epoch 2: val_loss improved from 0.79341 to 0.41849, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7137 - iou_coef: 0.5583 - loss: 0.2863 - precision_4: 0.7333 - recall_4: 0.7035 - val_dice_coef: 0.5833 - val_iou_coef: 0.4231 - val_loss: 0.4185 - val_precision_4: 0.9330 - val_recall_4: 0.4270
# Epoch 3/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7490 - iou_coef: 0.6021 - loss: 0.2509 - precision_4: 0.7674 - recall_4: 0.7449
# Epoch 3: val_loss improved from 0.41849 to 0.31898, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.7491 - iou_coef: 0.6022 - loss: 0.2509 - precision_4: 0.7674 - recall_4: 0.7449 - val_dice_coef: 0.6787 - val_iou_coef: 0.5202 - val_loss: 0.3190 - val_precision_4: 0.5768 - val_recall_4: 0.8713
# Epoch 4/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7649 - iou_coef: 0.6230 - loss: 0.2351 - precision_4: 0.7849 - recall_4: 0.7606
# Epoch 4: val_loss improved from 0.31898 to 0.28305, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7648 - iou_coef: 0.6230 - loss: 0.2351 - precision_4: 0.7849 - recall_4: 0.7606 - val_dice_coef: 0.7141 - val_iou_coef: 0.5610 - val_loss: 0.2831 - val_precision_4: 0.6331 - val_recall_4: 0.8665
# Epoch 5/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.7778 - iou_coef: 0.6391 - loss: 0.2222 - precision_4: 0.7956 - recall_4: 0.7722
# Epoch 5: val_loss improved from 0.28305 to 0.22603, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7777 - iou_coef: 0.6391 - loss: 0.2223 - precision_4: 0.7956 - recall_4: 0.7722 - val_dice_coef: 0.7734 - val_iou_coef: 0.6339 - val_loss: 0.2260 - val_precision_4: 0.7780 - val_recall_4: 0.7879
# Epoch 6/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7815 - iou_coef: 0.6448 - loss: 0.2185 - precision_4: 0.7966 - recall_4: 0.7801
# Epoch 6: val_loss improved from 0.22603 to 0.22162, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.7816 - iou_coef: 0.6449 - loss: 0.2184 - precision_4: 0.7966 - recall_4: 0.7801 - val_dice_coef: 0.7787 - val_iou_coef: 0.6416 - val_loss: 0.2216 - val_precision_4: 0.7754 - val_recall_4: 0.8031
# Epoch 7/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dice_coef: 0.7907 - iou_coef: 0.6565 - loss: 0.2092 - precision_4: 0.8132 - recall_4: 0.7804
# Epoch 7: val_loss did not improve from 0.22162
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - dice_coef: 0.7908 - iou_coef: 0.6565 - loss: 0.2092 - precision_4: 0.8132 - recall_4: 0.7805 - val_dice_coef: 0.6056 - val_iou_coef: 0.4440 - val_loss: 0.3952 - val_precision_4: 0.9352 - val_recall_4: 0.4618
# Epoch 8/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dice_coef: 0.7920 - iou_coef: 0.6581 - loss: 0.2080 - precision_4: 0.8195 - recall_4: 0.7775
# Epoch 8: val_loss did not improve from 0.22162
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - dice_coef: 0.7920 - iou_coef: 0.6581 - loss: 0.2080 - precision_4: 0.8195 - recall_4: 0.7775 - val_dice_coef: 0.6435 - val_iou_coef: 0.4812 - val_loss: 0.3540 - val_precision_4: 0.5191 - val_recall_4: 0.9076
# Epoch 9/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7957 - iou_coef: 0.6629 - loss: 0.2043 - precision_4: 0.8124 - recall_4: 0.7899
# Epoch 9: val_loss did not improve from 0.22162
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.7957 - iou_coef: 0.6629 - loss: 0.2043 - precision_4: 0.8125 - recall_4: 0.7899 - val_dice_coef: 0.6083 - val_iou_coef: 0.4435 - val_loss: 0.3901 - val_precision_4: 0.4757 - val_recall_4: 0.9072
# Epoch 10/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8043 - iou_coef: 0.6748 - loss: 0.1957 - precision_4: 0.8177 - recall_4: 0.8005
# Epoch 10: val_loss improved from 0.22162 to 0.21278, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8043 - iou_coef: 0.6748 - loss: 0.1957 - precision_4: 0.8177 - recall_4: 0.8005 - val_dice_coef: 0.7876 - val_iou_coef: 0.6539 - val_loss: 0.2128 - val_precision_4: 0.8610 - val_recall_4: 0.7397
# Epoch 11/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8102 - iou_coef: 0.6830 - loss: 0.1898 - precision_4: 0.8248 - recall_4: 0.8048
# Epoch 11: val_loss did not improve from 0.21278
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8102 - iou_coef: 0.6830 - loss: 0.1898 - precision_4: 0.8248 - recall_4: 0.8048 - val_dice_coef: 0.7573 - val_iou_coef: 0.6153 - val_loss: 0.2404 - val_precision_4: 0.6960 - val_recall_4: 0.8654
# Epoch 12/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8160 - iou_coef: 0.6910 - loss: 0.1840 - precision_4: 0.8343 - recall_4: 0.8061
# Epoch 12: val_loss did not improve from 0.21278
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8160 - iou_coef: 0.6910 - loss: 0.1840 - precision_4: 0.8343 - recall_4: 0.8061 - val_dice_coef: 0.7820 - val_iou_coef: 0.6462 - val_loss: 0.2159 - val_precision_4: 0.7377 - val_recall_4: 0.8612
# Epoch 13/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8066 - iou_coef: 0.6787 - loss: 0.1934 - precision_4: 0.8237 - recall_4: 0.8023
# Epoch 13: val_loss improved from 0.21278 to 0.20249, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8066 - iou_coef: 0.6787 - loss: 0.1933 - precision_4: 0.8238 - recall_4: 0.8024 - val_dice_coef: 0.7968 - val_iou_coef: 0.6654 - val_loss: 0.2025 - val_precision_4: 0.8275 - val_recall_4: 0.7854
# Epoch 14/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8137 - iou_coef: 0.6881 - loss: 0.1863 - precision_4: 0.8252 - recall_4: 0.8134
# Epoch 14: val_loss did not improve from 0.20249
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8137 - iou_coef: 0.6881 - loss: 0.1863 - precision_4: 0.8252 - recall_4: 0.8133 - val_dice_coef: 0.7303 - val_iou_coef: 0.5820 - val_loss: 0.2689 - val_precision_4: 0.8195 - val_recall_4: 0.6731
# Epoch 15/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8158 - iou_coef: 0.6908 - loss: 0.1841 - precision_4: 0.8318 - recall_4: 0.8089
# Epoch 15: val_loss did not improve from 0.20249
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8158 - iou_coef: 0.6908 - loss: 0.1841 - precision_4: 0.8318 - recall_4: 0.8089 - val_dice_coef: 0.7477 - val_iou_coef: 0.6019 - val_loss: 0.2529 - val_precision_4: 0.8815 - val_recall_4: 0.6505
# Epoch 16/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8230 - iou_coef: 0.7009 - loss: 0.1770 - precision_4: 0.8395 - recall_4: 0.8166
# Epoch 16: val_loss did not improve from 0.20249
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8230 - iou_coef: 0.7009 - loss: 0.1770 - precision_4: 0.8395 - recall_4: 0.8166 - val_dice_coef: 0.7968 - val_iou_coef: 0.6660 - val_loss: 0.2027 - val_precision_4: 0.8197 - val_recall_4: 0.7944
# Epoch 17/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8246 - iou_coef: 0.7028 - loss: 0.1754 - precision_4: 0.8394 - recall_4: 0.8184
# Epoch 17: val_loss did not improve from 0.20249
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8246 - iou_coef: 0.7028 - loss: 0.1754 - precision_4: 0.8394 - recall_4: 0.8184 - val_dice_coef: 0.7463 - val_iou_coef: 0.6000 - val_loss: 0.2543 - val_precision_4: 0.8751 - val_recall_4: 0.6663
# Epoch 18/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8199 - iou_coef: 0.6965 - loss: 0.1801 - precision_4: 0.8371 - recall_4: 0.8127
# Epoch 18: val_loss improved from 0.20249 to 0.20113, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - dice_coef: 0.8199 - iou_coef: 0.6965 - loss: 0.1801 - precision_4: 0.8371 - recall_4: 0.8127 - val_dice_coef: 0.7967 - val_iou_coef: 0.6662 - val_loss: 0.2011 - val_precision_4: 0.7864 - val_recall_4: 0.8317
# Epoch 19/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8230 - iou_coef: 0.7007 - loss: 0.1770 - precision_4: 0.8376 - recall_4: 0.8178
# Epoch 19: val_loss did not improve from 0.20113
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8230 - iou_coef: 0.7007 - loss: 0.1770 - precision_4: 0.8376 - recall_4: 0.8178 - val_dice_coef: 0.7945 - val_iou_coef: 0.6621 - val_loss: 0.2055 - val_precision_4: 0.8667 - val_recall_4: 0.7455
# Epoch 20/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8251 - iou_coef: 0.7042 - loss: 0.1749 - precision_4: 0.8405 - recall_4: 0.8212
# Epoch 20: val_loss did not improve from 0.20113
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8251 - iou_coef: 0.7042 - loss: 0.1749 - precision_4: 0.8405 - recall_4: 0.8212 - val_dice_coef: 0.7601 - val_iou_coef: 0.6178 - val_loss: 0.2405 - val_precision_4: 0.8718 - val_recall_4: 0.6839
# Epoch 21/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8218 - iou_coef: 0.6992 - loss: 0.1781 - precision_4: 0.8285 - recall_4: 0.8235
# Epoch 21: val_loss improved from 0.20113 to 0.19669, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8219 - iou_coef: 0.6992 - loss: 0.1781 - precision_4: 0.8285 - recall_4: 0.8235 - val_dice_coef: 0.8017 - val_iou_coef: 0.6725 - val_loss: 0.1967 - val_precision_4: 0.7846 - val_recall_4: 0.8419
# Epoch 22/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8327 - iou_coef: 0.7150 - loss: 0.1672 - precision_4: 0.8474 - recall_4: 0.8285
# Epoch 22: val_loss did not improve from 0.19669
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8327 - iou_coef: 0.7149 - loss: 0.1673 - precision_4: 0.8474 - recall_4: 0.8285 - val_dice_coef: 0.7629 - val_iou_coef: 0.6207 - val_loss: 0.2376 - val_precision_4: 0.9036 - val_recall_4: 0.6734
# Epoch 23/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8259 - iou_coef: 0.7053 - loss: 0.1741 - precision_4: 0.8405 - recall_4: 0.8209
# Epoch 23: val_loss did not improve from 0.19669
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8259 - iou_coef: 0.7053 - loss: 0.1741 - precision_4: 0.8405 - recall_4: 0.8210 - val_dice_coef: 0.7031 - val_iou_coef: 0.5488 - val_loss: 0.2946 - val_precision_4: 0.5928 - val_recall_4: 0.9172
# Epoch 24/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dice_coef: 0.8258 - iou_coef: 0.7049 - loss: 0.1742 - precision_4: 0.8415 - recall_4: 0.8210
# Epoch 24: val_loss improved from 0.19669 to 0.19092, saving model to Fold5_checkpoint.weights.h5
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8258 - iou_coef: 0.7049 - loss: 0.1742 - precision_4: 0.8414 - recall_4: 0.8210 - val_dice_coef: 0.8090 - val_iou_coef: 0.6825 - val_loss: 0.1909 - val_precision_4: 0.8473 - val_recall_4: 0.7905
# Epoch 25/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8353 - iou_coef: 0.7189 - loss: 0.1647 - precision_4: 0.8458 - recall_4: 0.8350
# Epoch 25: val_loss did not improve from 0.19092
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - dice_coef: 0.8353 - iou_coef: 0.7189 - loss: 0.1647 - precision_4: 0.8458 - recall_4: 0.8349 - val_dice_coef: 0.8025 - val_iou_coef: 0.6734 - val_loss: 0.1975 - val_precision_4: 0.8070 - val_recall_4: 0.8136
# Epoch 26/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8328 - iou_coef: 0.7152 - loss: 0.1672 - precision_4: 0.8426 - recall_4: 0.8346
# Epoch 26: val_loss did not improve from 0.19092
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - dice_coef: 0.8328 - iou_coef: 0.7152 - loss: 0.1672 - precision_4: 0.8426 - recall_4: 0.8346 - val_dice_coef: 0.7814 - val_iou_coef: 0.6446 - val_loss: 0.2185 - val_precision_4: 0.7622 - val_recall_4: 0.8245
# Epoch 27/30
# 300/302 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dice_coef: 0.8337 - iou_coef: 0.7164 - loss: 0.1663 - precision_4: 0.8476 - recall_4: 0.8285
# Epoch 27: val_loss did not improve from 0.19092
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - dice_coef: 0.8337 - iou_coef: 0.7164 - loss: 0.1662 - precision_4: 0.8475 - recall_4: 0.8285 - val_dice_coef: 0.7755 - val_iou_coef: 0.6380 - val_loss: 0.2224 - val_precision_4: 0.7321 - val_recall_4: 0.8553
# Epoch 28/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8342 - iou_coef: 0.7167 - loss: 0.1658 - precision_4: 0.8406 - recall_4: 0.8360
# Epoch 28: val_loss did not improve from 0.19092
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8342 - iou_coef: 0.7167 - loss: 0.1658 - precision_4: 0.8406 - recall_4: 0.8360 - val_dice_coef: 0.7977 - val_iou_coef: 0.6672 - val_loss: 0.2021 - val_precision_4: 0.7915 - val_recall_4: 0.8288
# Epoch 29/30
# 301/302 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8355 - iou_coef: 0.7191 - loss: 0.1645 - precision_4: 0.8504 - recall_4: 0.8308
# Epoch 29: val_loss did not improve from 0.19092
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - dice_coef: 0.8355 - iou_coef: 0.7191 - loss: 0.1645 - precision_4: 0.8504 - recall_4: 0.8308 - val_dice_coef: 0.8005 - val_iou_coef: 0.6711 - val_loss: 0.1984 - val_precision_4: 0.8509 - val_recall_4: 0.7732
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - dice_coef: 0.8153 - iou_coef: 0.6913 - loss: 0.1847 - precision_4: 0.8510 - recall_4: 0.8049
# Average Dice Coefficient: 0.7983
# Average IoU: 0.6683
# Average Recall: 0.8068
# Average Precision: 0.8190

# %%
# Find best model (highest Dice Coefficient)
best_fold = np.argmax(dice_scores)
print(f"Using best model from Fold {best_fold + 1} for test evaluation.")

# Load best fold model weights
best_model = mobilenet_unet()
best_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
                   loss=dice_loss, 
                   metrics=[dice_coef, iou_coef, tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])
best_model.load_weights(f'Fold{best_fold+1}_checkpoint.weights.h5')

# Evaluate on test set
test_results = best_model.evaluate(x_test, mask_test, batch_size=32)
print("Test Metrics:", test_results)
# Out:
# Using best model from Fold 5 for test evaluation.
# /home/gourib/mnt/sdb/conds_envs/newk/lib/python3.9/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 66 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - dice_coef: 0.6900 - iou_coef: 0.5514 - loss: 0.3099 - precision_5: 0.7596 - recall_5: 0.7233
# Test Metrics: [0.27712294459342957, 0.7233442068099976, 0.5827221870422363, 0.7217340469360352, 0.7862079739570618]
